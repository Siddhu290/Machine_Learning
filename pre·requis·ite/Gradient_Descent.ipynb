# %% [markdown]
# # Gradient Descent

# %% [markdown]
# Gradient Descent is an optimization algorithm for finding a local minimum of a differentiable function.
#
# Gradient descent in machine learning is simply used to find the values of a function's parameters (coefficients) that minimize a cost function as far as possible.
#
#  It is a first-order iterative algorithm for finding a local minimum of a differentiable multivariate function.

# %% [markdown]
# Why do We Need the Gradient Descent Algorithm?
#
# In many machine learning models, our ultimate goal is to find the best parameter values that reduce the cost associated with the predictions. To do this, we initially start with random values of these parameters and try to find the optimal ones. To find the optimal values, we use the gradient descent algorithm.
#
# How does the Gradient Descent Algorithm Work?
#
# Start with random initial values for the parameters.
#
# Predict the value of the target variable using the current parameters.
# Calculate the cost associated with the prediction.
# Have we minimized the cost? If yes, then go to step — 6. If no, then go to step — 5.
# Update the parameter values using the gradient descent algorithm and return to step — 2.
# We have our final updated parameters.
# Our model is ready to roll (down the mountain)!
#
# Figure — 1: How the gradient descent algorithm works
# The Formula of the Gradient Descent Algorithm:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Arbitally take 5 because algorithm starts at 3, where to we do starts
#
# How many parts to sepereate

# %%
cur_x = 5 # The algorithm starts at x=3
rate = 0.1 # Learning rate
precision = 0.5 # This tells us when to stop the alogrithm
previous_step_size = 1
max_iters = 1000000 # maximum number of iterations
iters = 0  # iteration counter

df = lambda x: 2*(x+5) # Gradient of our function

while previous_step_size > precision and iters < max_iters:
  prev_x = cur_x # store current x value in prev_x
  cur_x = cur_x - rate * df(prev_x) # Grad descent
  previous_step_size = abs(cur_x -prev_x) # Change in x
  iters = iters + 1 # iteration count
  print('Iteration',iters, "\n value is ",cur_x) # print interations

print('The local minimum occurs at', cur_x)
# Out:
# Iteration 1
#  value is  3.0
# Iteration 2
#  value is  1.4
# Iteration 3
#  value is  0.11999999999999966
# Iteration 4
#  value is  -0.9040000000000001
# Iteration 5
#  value is  -1.7232000000000003
# Iteration 6
#  value is  -2.3785600000000002
# Iteration 7
#  value is  -2.902848
# Iteration 8
#  value is  -3.3222784
# The local minimum occurs at -3.3222784

# %%
# docs.scipy.org

# %% [markdown]
# # Satistics

# %% [markdown]
# # About Pandas
#
# https://pandas.pydata.org/about/index.html

# %%
import pandas as pd
import numpy as np
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# creating the data sets with date
dates = pd.date_range("20130101", periods=6)

dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd

df = pd.DataFrame({'Name':['Rahul','Payal','Wardhan'],'Salary':[50000,54000,180000]})

# %%
df.head()
# Out:
#       Name  Salary
# 0    Rahul   50000
# 1    Payal   54000
# 2  Wardhan  180000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Salary  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
print(df['Salary'].mean())
# Out:
# 94666.66666666667

# %%
print(df['Salary'].mode())
print(df['Salary'].median())
# Out:
# 0     50000
# 1     54000
# 2    180000
# Name: Salary, dtype: int64
# 54000.0

# %%
df['Salary'].describe()['count']
# Out:
# 3.0

# %%
df['Salary'].describe()
# Out:
# count         3.000000
# mean      94666.666667
# std       73927.892797
# min       50000.000000
# 25%       52000.000000
# 50%       54000.000000
# 75%      117000.000000
# max      180000.000000
# Name: Salary, dtype: float64

# %% [markdown]
# # Inferencial Sta

# %% [markdown]
# ## Demo on Probability

# %%
# Creating a set with curly braces
Set1 = {4,7}
print(Set1)
print(type(Set1))
# Out:
# {4, 7}
# <class 'set'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Converting a list into as set
my_list = [1,2,3,4,4]
my_set_from_list = set(my_list)
print(my_set_from_list)
# Out:
# {1, 2, 3, 4}

# %%
my_set = set([3,5,7])
print('Here is my set : ',my_set)
print('3 is in the set: ',3 in my_set)
print('1 is in the set: ',1 in my_set)
print('6 is NOT in the set:',6 not in my_set)
# Out:
# Here is my set :  {3, 5, 7}
# 3 is in the set:  True
# 1 is in the set:  False
# 6 is NOT in the set: True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
