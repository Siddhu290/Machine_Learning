# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhu290/SSPU_Machine_Learning/blob/main/2024-07-01/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The pandas index provides the axis labels for the series and DataFrame objects.It can only contain hashable objects . A pandas Series has one Index

# %%
s4 = pd.Series(['a','b'])*3

# %%
print(s4)
# Out:
# 0    aaa
# 1    bbb
# dtype: object

# %%
s4.index
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
idx=s4.index

# %%
b =idx.is_monotonic_decreasing
print(b)
# Out:
# False

# %%
b =idx.is_monotonic_increasing
print(b)
# Out:
# True

# %%
b=idx.has_duplicates
print(b)
# Out:
# False

# %%
i=idx.nlevels
print(i)
# Out:
# 1

# %%
a =idx.values
print(a)
# Out:
# [0 1]

# %%
l=idx.tolist()
print(l)
# Out:
# [0, 1]

# %%
dtype='int'
idx=idx.astype(dtype)
print(idx)
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
b= idx.equals(0)
print(b)
# Out:
# False

# %%
i =idx.nunique()
print(i)
# Out:
# 2

# %%
label = idx.min()
print(label)
# Out:
# 0

# %%
label = idx.max()
print(label)
# Out:
# 1

# %%
from io import StringIO
data=""",  Animal,   Cuteness, Desirable
row-1,dog,8.7,True
row-2,bat,2.6,False"""
df=pd.read_csv(StringIO(data),
header=0,index_col=0,
skipinitialspace=True)

# %%
workbook = pd.ExcelFile('/content/Book1.xlsx')
dictionary={}
for sheet_name in workbook.sheet_names:
    df= workbook.parse(sheet_name)
    dictionary[sheet_name]=df

# %% [markdown]
# Dictionary to Series

# %%
import pandas as pd
s1= pd.Series(range(6))
s2 = s1 * s1
s2.index = s2.index + 2
df= pd.concat([s1,s2],axis=1)
s3 =pd.Series({'Tom':1,'Dick':4,'Har':9})
s4 =pd.Series({'Tom':3,'Dick':2,'Mar':5})
df = pd.concat({'A':s3, 'B':s4},axis=1)
df
# Out:
#         A    B
# Tom   1.0  3.0
# Dick  4.0  2.0
# Har   9.0  NaN
# Mar   NaN  5.0

# %%
df.info()
n =4
df =df.head(n)
df= df.tail(n)
df= df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Tom to Mar
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       3 non-null      float64
# dtypes: float64(2)
# memory usage: 96.0+ bytes

# %%
df.shape
# Out:
# (8, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.empty #True for empty DataFrame
# Out:
# False

# %%
df.size #Row Count * Column Count
# Out:
# 16

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# dtype: object

# %%
df.values
# Out:
# array([[3.        , 3.        ],
#        [4.66666667, 3.33333333],
#        [4.04145188, 1.52752523],
#        [1.        , 2.        ],
#        [2.5       , 2.5       ],
#        [4.        , 3.        ],
#        [6.5       , 4.        ],
#        [9.        , 5.        ]])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.copy()
# Out:
#               A         B
# count  3.000000  3.000000
# mean   4.666667  3.333333
# std    4.041452  1.527525
# min    1.000000  2.000000
# 25%    2.500000  2.500000
# 50%    4.000000  3.000000
# 75%    6.500000  4.000000
# max    9.000000  5.000000

# %%
df.rank()
# Out:
#          A    B
# count  3.0  4.5
# mean   6.0  6.0
# std    5.0  1.0
# min    1.0  2.0
# 25%    2.0  3.0
# 50%    4.0  4.5
# 75%    7.0  7.0
# max    8.0  8.0

# %%
df.astype(dtype)
# Out:
#        A  B
# count  3  3
# mean   4  3
# std    4  1
# min    1  2
# 25%    2  2
# 50%    4  3
# 75%    6  4
# max    9  5

# %% [markdown]
# # Saving the DATAFRAME

# %%
df.to_csv('shreyash.csv', encoding='utf-8')

# %% [markdown]
# #Saving DataFrames to an Excel Workbook

# %%
from pandas import ExcelWriter
writer = ExcelWriter('shreyash.xlsx')
df.to_excel(writer,'Sheet1')
df.to_excel(writer,'Sheet2')
writer.close()

# %% [markdown]
# # Get column index and labels

# %%
idx=df.columns
print(idx)
# Out:
# Index(['A', 'B'], dtype='object')

# %%
label =df.columns[0]
print(label)
# Out:
# A

# %%
df.rename(columns={'A':'X','B':'Y'},inplace=True)
print(df)
# Out:
#               X         Y
# count  3.000000  3.000000
# mean   4.666667  3.333333
# std    4.041452  1.527525
# min    1.000000  2.000000
# 25%    2.500000  2.500000
# 50%    4.000000  3.000000
# 75%    6.500000  4.000000
# max    9.000000  5.000000

# %% [markdown]
# #Selcting Columns

# %%
s=df['X']
print(s)
# Out:
# count    3.000000
# mean     4.666667
# std      4.041452
# min      1.000000
# 25%      2.500000
# 50%      4.000000
# 75%      6.500000
# max      9.000000
# Name: X, dtype: float64

# %% [markdown]
# # Selecting columns with python attributes

# %%
s=df.X
df.existin_col =df.X / df.Y
df['Z'] =df.X / df.Y
print(s)
# Out:
# count    3.000000
# mean     4.666667
# std      4.041452
# min      1.000000
# 25%      2.500000
# 50%      4.000000
# 75%      6.500000
# max      9.000000
# Name: X, dtype: float64
# <ipython-input-91-20cddcd4b816>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.existin_col =df.X / df.Y

# %% [markdown]
# #Adding a new columns

# %%
df['Z'] = range(len(df))
df
# Out:
#               X         Y  Z
# count  3.000000  3.000000  0
# mean   4.666667  3.333333  1
# std    4.041452  1.527525  2
# min    1.000000  2.000000  3
# 25%    2.500000  2.500000  4
# 50%    4.000000  3.000000  5
# 75%    6.500000  4.000000  6
# max    9.000000  5.000000  7

# %%
df['Z'] = np.repeat(np.nan,len(df))
df
# Out:
#               X         Y   Z
# count  3.000000  3.000000 NaN
# mean   4.666667  3.333333 NaN
# std    4.041452  1.527525 NaN
# min    1.000000  2.000000 NaN
# 25%    2.500000  2.500000 NaN
# 50%    4.000000  3.000000 NaN
# 75%    6.500000  4.000000 NaN
# max    9.000000  5.000000 NaN

# %%
df['random'] = np.random.rand(len(df))
df
# Out:
#               X         Y   Z    random
# count  3.000000  3.000000 NaN  0.767518
# mean   4.666667  3.333333 NaN  0.173728
# std    4.041452  1.527525 NaN  0.594549
# min    1.000000  2.000000 NaN  0.678977
# 25%    2.500000  2.500000 NaN  0.890130
# 50%    4.000000  3.000000 NaN  0.816758
# 75%    6.500000  4.000000 NaN  0.611579
# max    9.000000  5.000000 NaN  0.517915

# %%
df['index_as_col'] = df.index

# %%
df
# Out:
#               X         Y   Z    random index_as_col
# count  3.000000  3.000000 NaN  0.767518        count
# mean   4.666667  3.333333 NaN  0.173728         mean
# std    4.041452  1.527525 NaN  0.594549          std
# min    1.000000  2.000000 NaN  0.678977          min
# 25%    2.500000  2.500000 NaN  0.890130          25%
# 50%    4.000000  3.000000 NaN  0.816758          50%
# 75%    6.500000  4.000000 NaN  0.611579          75%
# max    9.000000  5.000000 NaN  0.517915          max

# %% [markdown]
# # Swap Columns

# %%
df[['X','Y']] = df[['Y','X']]
df
# Out:
#               X         Y   Z    random index_as_col
# count  3.000000  3.000000 NaN  0.767518        count
# mean   3.333333  4.666667 NaN  0.173728         mean
# std    1.527525  4.041452 NaN  0.594549          std
# min    2.000000  1.000000 NaN  0.678977          min
# 25%    2.500000  2.500000 NaN  0.890130          25%
# 50%    3.000000  4.000000 NaN  0.816758          50%
# 75%    4.000000  6.500000 NaN  0.611579          75%
# max    5.000000  9.000000 NaN  0.517915          max

# %% [markdown]
# #Dropping Columns

# %%
df=df.drop('Z',axis=1)
df
# Out:
#               X         Y    random index_as_col
# count  3.000000  3.000000  0.767518        count
# mean   3.333333  4.666667  0.173728         mean
# std    1.527525  4.041452  0.594549          std
# min    2.000000  1.000000  0.678977          min
# 25%    2.500000  2.500000  0.890130          25%
# 50%    3.000000  4.000000  0.816758          50%
# 75%    4.000000  6.500000  0.611579          75%
# max    5.000000  9.000000  0.517915          max

# %%
df.drop('Y',axis=1,inplace=True)
df
# Out:
#               X    random index_as_col
# count  3.000000  0.767518        count
# mean   3.333333  0.173728         mean
# std    1.527525  0.594549          std
# min    2.000000  0.678977          min
# 25%    2.500000  0.890130          25%
# 50%    3.000000  0.816758          50%
# 75%    4.000000  0.611579          75%
# max    5.000000  0.517915          max

# %%
df
# Out:
#               X    random index_as_col
# count  3.000000  0.767518        count
# mean   3.333333  0.173728         mean
# std    1.527525  0.594549          std
# min    2.000000  0.678977          min
# 25%    2.500000  0.890130          25%
# 50%    3.000000  0.816758          50%
# 75%    4.000000  0.611579          75%
# max    5.000000  0.517915          max
