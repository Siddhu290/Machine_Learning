# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhu290/Machine_Learning/blob/main/2024-07-19/Dynamic_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Dynamic Programming (DP)**

# %% [markdown]
# 1].Dynamic Programming (DP) is used for optimization problems.
#
# 2].Similar to divide-and-conquer, DP solves problems by combining solutions to sub-problems.
#
# 3].DP solves each sub-problem only once, storing the solution to avoid re-computation.

# %% [markdown]
# ##Key Properties

# %% [markdown]
# **Overlapping Sub-Problems:**
#
# 1].Problems where the solution of one
# sub-problem is needed multiple times.
#
# 2].Solutions are stored (memorization) to avoid repeated computation.
#
# 3].Example: Recursive Fibonacci sequence has many overlapping sub-problems.

# %% [markdown]
# **Optimal Substructure:**
#
# A problem has an optimal substructure if its optimal solution can be constructed from optimal solutions of its sub-problems.
#
#
# Example: In the shortest path problem, if a node
# 𝑥
# x is on the shortest path from
# 𝑢
# u to
# 𝑣
# v, the path from
# 𝑢
# u to
# 𝑣
# v is a combination of the shortest path from
# 𝑢
# u to
# 𝑥
# x and
# 𝑥
# x to
# 𝑣
# v.

# %% [markdown]
# **Example Algorithms**
#
# Floyd-Warshall and Bellman-Ford algorithms for finding the shortest path are typical examples of DP.

# %% [markdown]
# ##Steps to Design a DP Algorithm

# %% [markdown]
# **1].Characterize the Structure of an Optimal Solution:**
#
# -Understand how a solution can be broken into sub-problems.
#
# **2].Recursively Define the Value of an Optimal Solution:**
#
# -Establish a recursive relationship between the problem and its sub-problems.
#
# **3].Compute the Value of an Optimal Solution:**
#
# -Use a bottom-up approach to solve sub-problems and build up to the solution of the main problem.
#
# **4].Construct an Optimal Solution:**
#
# -Reconstruct the solution from the computed values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Elements of Dynamic Programming**

# %% [markdown]
# 1. Substructure:
#
# 2. Table Structure:
#
# 3. Bottom-up Computation:

# %% [markdown]
# ## **Applications of dynamic programming**

# %% [markdown]
# 1. 0/1 knapsack problem
#
# 2. All pair Shortest path problem
#
# 3. Reliability design problem
#
# 4. Longest common subsequence (LCS)
#
# 5. Flight control and robotics control
#
# 6. Time-sharing: It schedules the job to maximize CPU usage

# %% [markdown]
# ## **Longest Common Sequence (LCS)**

# %% [markdown]
# The Longest Common Subsequence (LCS) is the longest sequence that can be derived from two strings by deleting some characters without changing the order of the remaining characters.

# %% [markdown]
# ## DAA - Travelling Salesman Problem

# %% [markdown]
# A traveler needs to visit all the cities from a list, where distances between all the cities are
# known and each city should be visited just once. What is the shortest possible route that he
# visits each city exactly once and returns to the origin city?

# %% [markdown]
# Example
#
# In the following example, we will illustrate the steps to solve the travelling salesman problem.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Shortest Path Problem | Shortest Path| Algorithms | Examples

# %% [markdown]
# ## Shortest Path Problem-
#
# • In data structures/ADA,
#
# • Shortest path problem is a problem of finding the shortest path(s) between vertices of a
# given graph.
#
# • Shortest path between two vertices is a path that has the least cost as compared to all
# other existing paths.
#
# ## Shortest Path Algorithms-
#
# • Shortest path algorithms are a family of algorithms used for solving the shortest path
# problem.
#
# ## Applications
#
# -Shortest path algorithms have a wide range of applications such as in-
#
# • Google Maps
#
# • Road Networks
#
# •  Logistics Research

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Dijkstra’s Algorithm

# %% [markdown]
# • Dijkstra Algorithm is a very famous greedy algorithm.
#
# • It is used for solving the single source shortest path problem.
#
# • It computes the shortest path from one particular source node to all other remaining nodes
# of the graph.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## BACKTRACKING

# %% [markdown]
# **Definition:**
#
# Backtracking is used to solve problems where a sequence of objects is chosen from a set, ensuring the sequence satisfies certain criteria.
#
#
# **Example - 4 Queens Problem:**
#
# Place 4 queens on a 4x4 chessboard so that no two queens attack each other.
# Explicit Constraint: Each queen must be placed in one of the columns {1, 2, 3, 4}.
# Implicit Constraints: No two queens can be in the same column or diagonal.
#
#  **Backtracking Process:**
#
# Form partial solutions, check their validity against constraints, and backtrack if a solution seems unpromising.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Trees

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Creating the binary tree
root = {'data': 0, 'left': None, 'right': None, 'parent': None}
root['left'] = {'data': 1, 'left': None, 'right': None, 'parent': root}
root['right'] = {'data': 2, 'left': None, 'right': None, 'parent': root}

l = root['left']
l['left'] = {'data': 3, 'left': None, 'right': None, 'parent': l}

r = root['right']
r['left'] = {'data': 4, 'left': None, 'right': None, 'parent': r}
r['right'] = {'data': 5, 'left': None, 'right': None, 'parent': r}

x = r['left']
x['left'] = {'data': 6, 'left': None, 'right': None, 'parent': x}
x['right'] = {'data': 7, 'left': None, 'right': None, 'parent': x}

# Preorder traversal
def preorder(T):
    if T is None:
        return
    print(T['data'], end=" ")
    preorder(T['left'])
    preorder(T['right'])

# Inorder traversal
def inorder(T):
    if T is None:
        return
    inorder(T['left'])
    print(T['data'], end=" ")
    inorder(T['right'])

# Performing traversals
print("Preorder traversal: ")
preorder(root)

print("\nInorder traversal: ")
inorder(root)
# Out:
# Preorder traversal:
# 0 1 3 2 4 6 7 5
# Inorder traversal:
# 3 1 0 6 4 7 2 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def print_tree(tree, f):
    N = len(tree)
    print(N, file=f)
    for i in range(N):
        left_index = tree[i]['left'] if tree[i]['left'] is not None else 'None'
        right_index = tree[i]['right'] if tree[i]['right'] is not None else 'None'
        print(tree[i]['data'], left_index, right_index, file=f)

tree = [
    {'data': 0, 'left': 1, 'right': 2, 'parent': None},
    {'data': 1, 'left': 3, 'right': None, 'parent': 0},
    {'data': 2, 'left': 4, 'right': 5, 'parent': 0},
    {'data': 3, 'left': None, 'right': None, 'parent': 1},
    {'data': 4, 'left': 6, 'right': 7, 'parent': 2},
    {'data': 5, 'left': None, 'right': None, 'parent': 2},
    {'data': 6, 'left': None, 'right': None, 'parent': 4},
    {'data': 7, 'left': None, 'right': None, 'parent': 4},
]


import sys
print_tree(tree, sys.stdout)
# Out:
# 8
# 0 1 2
# 1 3 None
# 2 4 5
# 3 None None
# 4 6 7
# 5 None None
# 6 None None
# 7 None None

# %%
def read_tree(filename):
    with open(filename) as f:
        for line in f:
            fields = list(map(int, line.split()))
            if len(fields) == 1:
                N = int(fields[0])
                tree = [{'data': None, 'left': None, 'right': None, 'parent': None} for _ in range(N)]
                index = 0
            else:
                tree[index]['data'] = fields[0]
                tree[index]['left'] = fields[1] if fields[1] != -1 else None
                tree[index]['right'] = fields[2] if fields[2] != -1 else None
                index += 1
    return tree


example_tree = [
    {'data': 0, 'left': 1, 'right': 2, 'parent': None},
    {'data': 1, 'left': 3, 'right': None, 'parent': 0},
    {'data': 2, 'left': 4, 'right': 5, 'parent': 0},
    {'data': 3, 'left': None, 'right': None, 'parent': 1},
    {'data': 4, 'left': 6, 'right': 7, 'parent': 2},
    {'data': 5, 'left': None, 'right': None, 'parent': 2},
    {'data': 6, 'left': None, 'right': None, 'parent': 4},
    {'data': 7, 'left': None, 'right': None, 'parent': 4},
]

filename = 'tree.txt'


with open(filename, 'w') as f:
    print(len(example_tree), file=f)
    for node in example_tree:
        left = node['left'] if node['left'] is not None else -1
        right = node['right'] if node['right'] is not None else -1
        print(node['data'], left, right, file=f)


tree_from_file = read_tree(filename)

import sys
print_tree(tree_from_file, sys.stdout)
# Out:
# 8
# 0 1 2
# 1 3 None
# 2 4 5
# 3 None None
# 4 6 7
# 5 None None
# 6 None None
# 7 None None

# %%
def read_tree(filename):
    with open(filename) as f:  # 'with' ensures the file is properly closed
        for line in f:
            fields = list(map(int, line.split()))
            if len(fields) == 1:  # This is the first line
                N = int(fields[0])
                tree = [{'data': None, 'left': None, 'right': None, 'parent': None} for _ in range(N)]
                index = 0
            else:
                tree[index]['data'] = fields[0]
                tree[index]['left'] = fields[1] if fields[1] != -1 else None
                tree[index]['right'] = fields[2] if fields[2] != -1 else None
                index += 1
    return tree

# %%
from random import randint

def generate_random_tree(tree, start_index, num_nodes):
    left = randint(0, num_nodes - 1)
    right = num_nodes - left - 1
    tree[start_index]['data'] = randint(1, 10 * num_nodes)

    if left > 0:
        tree[start_index]['left'] = start_index + 1
        generate_random_tree(tree, start_index + 1, left)
    else:
        tree[start_index]['left'] = -1

    if right > 0:
        tree[start_index]['right'] = start_index + left + 1
        generate_random_tree(tree, start_index + left + 1, right)
    else:
        tree[start_index]['right'] = -1

    return

# Example usage
num_nodes = 7
tree = [{'data': None, 'left': None, 'right': None, 'parent': None} for _ in range(num_nodes)]
generate_random_tree(tree, 0, num_nodes)

# Print the generated tree
import sys
print_tree(tree, sys.stdout)
# Out:
# 7
# 21 1 -1
# 37 2 6
# 39 3 5
# 18 4 -1
# 1 -1 -1
# 8 -1 -1
# 6 -1 -1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

root = TreeNode('R')
nodeA = TreeNode('A')
nodeB = TreeNode('B')
nodeC = TreeNode('C')
nodeD = TreeNode('D')
nodeE = TreeNode('E')
nodeF = TreeNode('F')
nodeG = TreeNode('G')

root.left = nodeA
root.right = nodeB

nodeA.left = nodeC
nodeA.right = nodeD

nodeB.left = nodeE
nodeB.right = nodeF

nodeF.left = nodeG

def preOrderTraversal(node):
    if node is None:
        return
    print(node.data, end=", ")
    preOrderTraversal(node.left)
    preOrderTraversal(node.right)


preOrderTraversal(root)
# Out:
# R, A, C, D, B, E, F, G,

# %%
def inOrderTraversal(node):
    if node is None:
        return
    inOrderTraversal(node.left)
    print(node.data, end=", ")
    inOrderTraversal(node.right)

inOrderTraversal(root)
# Out:
# C, A, D, R, E, B, G, F,

# %%
def postOrderTraversal(node):
    if node is None:
        return
    postOrderTraversal(node.left)
    postOrderTraversal(node.right)
    print(node.data, end=", ")

postOrderTraversal(root)
# Out:
# C, D, A, E, G, F, B, R,

# %% [markdown]
# ## array implementation should be a "perfect" Binary Tree, or a nearly perfect one

# %% [markdown]
# ## Binary Search Trees

# %%
class TreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def insert(root, data):
    if root is None:
        return TreeNode(data)
    if data > root.data:
        root.left = insert(root.left, data)
    else:
        root.right = insert(root.right, data)

insert(root, 10)
insert(root, 5)
insert(root, 15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-2f2cfd8956a2> in <cell line: 15>()
#      13         root.right = insert(root.right, data)
#      14
# ---> 15 insert(root, 10)
#      16 insert(root, 5)
#      17 insert(root, 15)
#
# <ipython-input-28-2f2cfd8956a2> in insert(root, data)
#       8     if root is None:
#       9         return TreeNode(data)
# ---> 10     if data > root.data:
#      11         root.left = insert(root.left, data)
#      12     else:
#
# TypeError: '>' not supported between instances of 'int' and 'str'
