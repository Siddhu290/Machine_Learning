# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhu290/Machine_Learning/blob/main/2024-07-17/Hypothesis_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# T-Test

# %%
import numpy as np
import scipy.stats as stats

# %%
student_score=np.array([72,89,65,73,79,84,63,76,85,75])
mu=70

# %%
t_state,p_value=stats.ttest_1samp(student_score,mu)
print("P-value",p_value)
if p_value<0.05:
  print("Reject null hypothesis")
else:
  print("Accept null hypothesis")
# Out:
# P-value 0.047816221110566944
# Reject null hypothesis

# %%
import seaborn as sns
import numpy as np

# %%
iris=sns.load_dataset('iris')

# %%
setosa=iris[iris['species']=='setosa']
versicolor=iris[iris['species']=='versicolor']

# %%
setosa_petal_length=setosa['petal_length']
versicolor_petal_length=versicolor['petal_length']

# %%
t_stat,p_value=stats.ttest_ind(setosa_petal_length,versicolor_petal_length)
alpha=0.5
if p_value<alpha:
  print("Reject the null hypothesi")
else:
  print("fail to reject null hypothesis")
# Out:
# Reject the null hypothesi

# %%
p_value
# Out:
# 5.404910513441677e-62

# %%
verginica=iris[iris['species']=='virginica']
sat=iris[iris['species']=='setosa']

# %%
setosa_petal_length=verginica['petal_length']
versicolor_petal_length=sat['petal_length']

# %%
t_stat,p_value=stats.ttest_ind(setosa_petal_length,versicolor_petal_length)
alpha=0.5
if p_value<alpha:
  print("Reject the null hypothesi")
else:
  print("fail to reject null hypothesis")
# Out:
# Reject the null hypothesi

# %%
iris["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ##write a program to implement stack in python add function push,pop,delete

# %%
class stack:
  def __init__(self):
    self.stack=[]

  def push(self,item):
    self.stack.append(item)
    print(f"item added in stack {self.stack}")

  def pop(self,it):
    if len(self.stack)==0:
      print("stack is empty")
    else:
      return self.stack.pop(it)




stack = stack()
stack.push(1)
stack.push(2)
stack.push(3)
stack.push(1)
stack.push(2)
stack.push(3)


stack.pop(0)
print(stack.stack)
# Out:
# item added in stack [1]
# item added in stack [1, 2]
# item added in stack [1, 2, 3]
# item added in stack [1, 2, 3, 1]
# item added in stack [1, 2, 3, 1, 2]
# item added in stack [1, 2, 3, 1, 2, 3]
# [2, 3, 1, 2, 3]

# %%
stack=stack()

# %%
class linklist:
  def __init__(self):
    self.head=None
    self.tail=None
    self.size=0

  def add(self,item):
    node=Node(item)
    if self.head==None:
      self.head=node
      self.tail=node
    else:
      self.tail.next=node
      self.tail=node
    self.size+=1

first=linklist()
first.add(2)

# %%
class que:
  def __init__(self):
    self.queue=[]
    self.size=0

  def enqueue(self,item):
    self.queue.append(item)
    self.size+=1
