# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddhu290/Machine_Learning/blob/main/2024-07-22/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
path="/content/4b5fd341ed56b734a5de24945fcd1c36.jpg"

# %%
image=cv2.imread(path)

# %%
cv2_imshow(image)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1500x2000>

# %%
grey=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(grey)
cv2.waitKey()
cv2.destroyAllWindows()

cv2.imwrite("grey.jpg",grey)
# Out:
# <PIL.Image.Image image mode=L size=1500x2000>
# True
